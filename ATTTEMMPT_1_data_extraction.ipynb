# %% [markdown]
# <a href="https://colab.research.google.com/github/4sciencee/MIS433-Final-Project/blob/main/ATTTEMMPT_1_data_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/4sciencee/MIS433-Final-Project.git
# Out:
# fatal: destination path 'MIS433-Final-Project' already exists and is not an empty directory.

# %%
import os

# Define your repository folder name
repo_name = 'MIS433-Final-Project'

# Check if we are already in the directory, if not, change to it
if not os.getcwd().endswith(repo_name):
    # If the folder exists, just go into it
    if os.path.exists(repo_name):
        # %cd {repo_name}
    else:
        # If it doesn't exist, clone it first
        # !git clone https://github.com/4sciencee/MIS433-Final-Project.git
        # %cd {repo_name}

# IMPORTANT: If you are still seeing the 'nested' folder issue,
# step one level deeper into the second folder
if os.path.exists(repo_name):
    # %cd {repo_name}

print("Current working directory:", os.getcwd())
print("Files in this directory:", os.listdir())
# Out:
# /content/MIS433-Final-Project/MIS433-Final-Project/MIS433-Final-Project/MIS433-Final-Project
# Current working directory: /content/MIS433-Final-Project/MIS433-Final-Project/MIS433-Final-Project/MIS433-Final-Project
# Files in this directory: ['data', 'MIS433-Final-Project', 'historical_ai_stocks.csv', '.git', 'nlp-financial-news-sentiment-analysis.ipynb']

# %%
import pandas as pd

# Check where the file is: if it's in the current folder, load it directly
# If you put it in a 'data' folder, use 'data/historical_ai_stocks.csv'
file_path = 'historical_ai_stocks.csv'

if os.path.exists(file_path):
    df = pd.read_csv(file_path)
    print("Success! Data loaded successfully.")
    print("-" * 50)
    print(df.head())
else:
    print("Error: Could not find the file in the current directory.")
    print("Available files:", os.listdir())
# Out:
# Success! Data loaded successfully.
# --------------------------------------------------
#          Date               Close                High                 Low  \
# 0         NaN                NVDA                NVDA                NVDA
# 1  2021-05-27   15.44905948638916  15.710400841238286  15.421130006657025
# 2  2021-05-28  16.203659057617188  16.236577036281336   15.46202947906416
# 3  2021-06-01  16.223604202270508   16.34704373015847  15.863262605463245
# 4  2021-06-02  16.736068725585938  16.876216524208118  16.194683808700496
#
#                 Open       Volume Ticker Close.1 High.1 Low.1  ... Close.4  \
# 0               NVDA         NVDA    NaN    MSFT   MSFT  MSFT  ...     AMD
# 1  15.66027712813999  581476000.0   NVDA     NaN    NaN   NaN  ...     NaN
# 2  15.46202947906416  644536000.0   NVDA     NaN    NaN   NaN  ...     NaN
# 3  16.22909116453109  472804000.0   NVDA     NaN    NaN   NaN  ...     NaN
# 4  16.21139203355558  594168000.0   NVDA     NaN    NaN   NaN  ...     NaN
#
#   High.4 Low.4 Open.4 Volume.4 Close.5 High.5 Low.5 Open.5 Volume.5
# 0    AMD   AMD    AMD      AMD    AVGO   AVGO  AVGO   AVGO     AVGO
# 1    NaN   NaN    NaN      NaN     NaN    NaN   NaN    NaN      NaN
# 2    NaN   NaN    NaN      NaN     NaN    NaN   NaN    NaN      NaN
# 3    NaN   NaN    NaN      NaN     NaN    NaN   NaN    NaN      NaN
# 4    NaN   NaN    NaN      NaN     NaN    NaN   NaN    NaN      NaN
#
# [5 rows x 32 columns]

# %%
# Check for missing values which could break your prediction model
missing_values = df.isnull().sum()
print("Missing values per column:")
print(missing_values)

# Drop or fill missing values if necessary
# df = df.dropna()
# Out:
# Missing values per column:
# Date           1
# Close       6270
# High        6270
# Low         6270
# Open        6270
# Volume      6270
# Ticker         1
# Close.1     6270
# High.1      6270
# Low.1       6270
# Open.1      6270
# Volume.1    6270
# Close.2     6270
# High.2      6270
# Low.2       6270
# Open.2      6270
# Volume.2    6270
# Close.3     6270
# High.3      6270
# Low.3       6270
# Open.3      6270
# Volume.3    6270
# Close.4     6270
# High.4      6270
# Low.4       6270
# Open.4      6270
# Volume.4    6270
# Close.5     6270
# High.5      6270
# Low.5       6270
# Open.5      6270
# Volume.5    6270
# dtype: int64
